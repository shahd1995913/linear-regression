# %% [markdown]
# ## Load the data you receive into a Pandas DataFrame

# %%
import pandas as pd

from sklearn.metrics import r2_score

import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split

# %%
weather_df = pd.read_csv("weather.csv")
weather_df
# Out:
#      Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  Max_Dew_Point_F  \
# 0                   71                62.0                54               55
# 1                   63                59.0                55               52
# 2                   62                58.0                54               53
# 3                   71                61.0                52               49
# 4                   64                60.0                57               55
# ..                 ...                 ...               ...              ...
# 684                 72                66.0                61               57
# 685                 75                68.0                59               54
# 686                 81                68.0                55               55
# 687                 70                64.0                57               55
# 688                 71                65.0                59               61
#
# ...

# %% [markdown]
# ## Show the first five rows of the data set.

# %%
weather_df.head()
# Out:
#    Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  Max_Dew_Point_F  \
# 0                 71                62.0                54               55
# 1                 63                59.0                55               52
# 2                 62                58.0                54               53
# 3                 71                61.0                52               49
# 4                 64                60.0                57               55
#
#    MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  Mean_Humidity  Min_Humidity  \
# 0               51              46            87             68            46
# 1               51              50            88             78            63
# 2               50              46            87             77            67
# 3               46              42            83             61            36
# 4               51              41            87             72            46
#
# ...

# %% [markdown]
# ##  Show the description and the info of the data set.

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Max_Temperature_F           689 non-null    int64
#  1   Mean_Temperature_F          688 non-null    float64
#  2   Min_TemperatureF            689 non-null    int64
#  3   Max_Dew_Point_F             689 non-null    int64
#  4   MeanDew_Point_F             689 non-null    int64
#  5   Min_Dewpoint_F              689 non-null    int64
#  6   Max_Humidity                689 non-null    int64
#  7   Mean_Humidity               689 non-null    int64
#  8   Min_Humidity                689 non-null    int64
#  9   Max_Sea_Level_Pressure_In   689 non-null    float64
#  10  Mean_Sea_Level_Pressure_In  689 non-null    float64
#  11  Min_Sea_Level_Pressure_In   689 non-null    float64
#  12  Max_Visibility_Miles        689 non-null    int64
# ...

# %%
weather_df.describe()
# Out:
#        Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# count         689.000000          688.000000        689.000000
# mean           64.027576           56.584302         49.454282
# std            12.427843           10.408058          9.451437
# min            39.000000           33.000000         23.000000
# 25%            55.000000           48.000000         43.000000
# 50%            63.000000           56.000000         50.000000
# 75%            73.000000           65.000000         57.000000
# max            98.000000           83.000000         70.000000
#
#        Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# count       689.000000       689.000000      689.000000    689.000000
# mean         48.571843        45.021771       40.873730     84.541364
# std           7.501230         7.914025        8.854608      9.718948
# min          10.000000         4.000000        1.000000     40.000000
# ...

# %% [markdown]
# ## Using a regression model, split your data into train and test data.

# %%
temp = weather_df["Min_TemperatureF"].values
Dewpoint = weather_df["Min_Dewpoint_F"].values
print(temp)
print(Dewpoint)
# Out:
# [54 55 54 52 57 59 55 55 55 57 50 51 52 48 45 51 54 55 52 48 45 55 55 53
#  54 45 42 48 43 36 32 30 28 27 28 30 30 36 44 50 45 44 39 51 57 55 39 27
#  27 26 26 33 39 46 48 43 50 51 54 50 48 41 37 42 44 44 46 46 46 53 42 43
#  41 37 39 42 41 35 30 26 27 32 33 41 54 46 44 39 39 44 46 45 41 37 36 44
#  39 48 46 39 33 45 50 55 50 46 50 46 42 39 39 44 44 44 42 48 53 51 48 48
#  48 45 51 46 48 42 45 44 39 48 50 44 36 33 36 46 48 48 37 35 39 32 32 37
#  39 37 37 41 44 51 53 52 54 46 46 43 46 48 51 50 43 42 46 48 52 50 52 51
#  55 46 44 43 44 39 39 46 48 46 45 48 44 46 42 39 39 41 46 48 46 48 46 43
#  46 46 46 42 53 51 48 50 54 51 45 46 48 48 46 48 51 55 53 55 53 53 53 55
#  55 55 57 54 57 57 55 55 55 57 57 57 61 53 57 57 57 57 57 57 59 61 60 61
#  55 55 57 52 57 61 55 57 62 59 57 60 57 55 66 64 66 66 70 69 62 64 68 68
#  63 66 63 61 63 62 64 64 64 66 64 63 64 60 66 69 66 62 61 62 59 62 60 55
#  61 62 66 68 64 64 68 61 57 62 62 62 61 66 66 66 63 62 60 60 60 64 64 61
# ...

# %%
plt.scatter(temp,Dewpoint)
plt.show()

# %%
temperature_vector = temp.reshape(-1,1)
temperature_vector
# Out:
# array([[54],
#        [55],
#        [54],
#        [52],
#        [57],
#        [59],
#        [55],
#        [55],
#        [55],
#        [57],
#        [50],
#        [51],
#        [52],
#        [48],
#        [45],
#        [51],
#        [54],
#        [55],
#        [52],
#        [48],
#        [45],
#        [55],
#        [55],
#        [53],
#        [54],
#        [45],
#        [42],
#        [48],
#        [43],
#        [36],
#        [32],
#        [30],
#        [28],
#        [27],
#        [28],
#        [30],
#        [30],
#        [36],
#        [44],
#        [50],
#        [45],
#        [44],
#        [39],
#        [51],
#        [57],
#        [55],
#        [39],
#        [27],
#        [27],
#        [26],
#        [26],
#        [33],
#        [39],
#        [46],
#        [48],
#        [43],
#        [50],
#        [51],
#        [54],
#        [50],
#        [48],
#        [41],
#        [37],
#        [42],
#        [44],
#        [44],
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(temperature_vector,Dewpoint,train_size=0.8,test_size=0.2,random_state=100)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shape {x_test.shape}")
print(f"y_test shape {y_test.shape}")
plt.scatter(weather_df['Min_TemperatureF'],weather_df['Min_Dewpoint_F'],color='#603DDB')
# Out:
# X_train shape (551, 1)
# y_train shape (551,)
# X_test shape (138, 1)
# y_test shape (138,)

# %%
x_train, x_test,y_train,y_test = train_test_split(temperature_vector,Dewpoint,test_size =0.1 , random_state=100)
x_train
# Out:
# array([[57],
#        [30],
#        [60],
#        [39],
#        [42],
#        [53],
#        [51],
#        [48],
#        [45],
#        [35],
#        [61],
#        [43],
#        [50],
#        [57],
#        [44],
#        [66],
#        [54],
#        [42],
#        [39],
#        [46],
#        [48],
#        [46],
#        [46],
#        [42],
#        [30],
#        [59],
#        [53],
#        [48],
#        [54],
#        [57],
#        [57],
#        [55],
#        [57],
#        [55],
#        [36],
#        [55],
#        [39],
#        [41],
#        [45],
#        [62],
#        [60],
#        [39],
#        [37],
#        [46],
#        [50],
#        [50],
#        [43],
#        [53],
#        [48],
#        [52],
#        [43],
#        [32],
#        [51],
#        [37],
#        [48],
#        [35],
#        [50],
#        [36],
#        [45],
#        [57],
#        [54],
#        [30],
#        [41],
#        [39],
#        [45],
#        [39],
# ...

# %%
plt.scatter(x_train,y_train,color='#2E2255')
plt.xlabel('Temperature')
plt.ylabel('Dewpoint')
plt.title('Dewpoint vs Temperature')
plt.show()

# %% [markdown]
# ## Fit your training split to the regression model.
# ## Using a regression model, split your data into train and test data.

# %%
lm = LinearRegression()

lm.fit(x_train,y_train)

print(f" The train Accuracy {round(lm.score(x_train,y_train)*100,2)} %")

print(f"The test Accuracy {round(lm.score(x_test,y_test)*100,2)} %")
# Out:
#  The train Accuracy 68.75 %
# The test Accuracy 70.69 %

# %%
plt.scatter(x_train, y_train, color = '#6B62F4')

plt.plot(x_train, lm.predict(x_train), color = '#221557')

plt.title('Dewpoint vs Temperature (In the training set)')

plt.xlabel('Temperature')

plt.ylabel('Dewpoint')

plt.show()

# %% [markdown]
# ## Show your regression model’s score.

# %%
print("The accurcy scores :", r2_score(y_test, lm.predict(x_test))*100 )
# Out:
# The accurcy scores : 70.68622114492126

# %%
weather_df.corr()
print("The corrolation  is : ", weather_df.corr())
# Out:
# The corrolation  is :                              Max_Temperature_F  Mean_Temperature_F  \
# Max_Temperature_F                    1.000000            0.970604
# Mean_Temperature_F                   0.970604            1.000000
# Min_TemperatureF                     0.850757            0.950002
# Max_Dew_Point_F                      0.728071            0.804748
# MeanDew_Point_F                      0.716776            0.813847
# Min_Dewpoint_F                       0.618153            0.736988
# Max_Humidity                        -0.538677           -0.521249
# Mean_Humidity                       -0.673360           -0.584973
# Min_Humidity                        -0.645518           -0.521134
# Max_Sea_Level_Pressure_In           -0.245586           -0.304912
# Mean_Sea_Level_Pressure_In          -0.113305           -0.174619
# Min_Sea_Level_Pressure_In           -0.004340           -0.063535
# Max_Visibility_Miles                 0.076832            0.082847
# ...

# %% [markdown]
# # Three conclusions
# ## 1. The accurcy scores : 70.68622114492126 this is mean there is a postive relation between the Temperature and Dewpoint
# ## 2. There is No  corrolation between the Max_Wind_Speed_MPH  and Max_Temperature_F due the corrolation in Negative
# ## 3. When the test_size is more then the accurcy will be incress
